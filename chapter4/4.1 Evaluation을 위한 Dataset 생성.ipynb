# %%
from langsmith import Client

# LangSmith 클라이언트 생성
client = Client()

# Golden Dataset 이름 설정 및 생성
dataset_name = "income_tax_dataset"
dataset = client.create_dataset(dataset_name)

# Golden Dataset에 예제 추가
client.create_examples(
    # 질문 목록
    inputs=[
        {"question": "제1조에 따른 소득세법의 목적은 무엇인가요?"},
        {"question": "'거주자'는 소득세법에서 어떻게 정의되나요?"},
        {"question": "'비거주자'는 소득세법에 따라 어떻게 정의되나요?"},
        {"question": "소득세법에 따른 '내국법인'은 누구를 의미하나요?"},
        {"question": "소득세법에 따라 소득세를 납부할 의무가 있는 사람은 누구인가요?"},
        {"question": "거주자의 과세 범위는 무엇인가요?"},
        {"question": "소득세법에 따라 소득은 어떻게 분류되나요?"},
        {"question": "종합소득이란 무엇인가요?"},
        {"question": "세금이 면제되는 소득의 종류는 무엇인가요?"},
        {"question": "소득세의 과세기간은 어떻게 되나요?"},
        {"question": "거주자의 소득세 납세지는 어디인가요?"},
        {"question": "비거주자의 소득세 납세지는 어디인가요?"},
        {"question": "납세지가 불분명한 경우 어떻게 되나요?"},
        {"question": "원천징수세액의 납세지는 어떻게 결정되나요?"},
        {"question": "납세자의 사망 시 납세지는 어떻게 되나요?"},
        {"question": "신탁 소득에 대한 납세의 범위는 무엇인가요?"},
        {"question": "원천징수 대상 소득은 무엇인가요?"},
        {"question": "공동 소유 자산의 양도소득은 어떻게 과세되나요?"},
        {"question": "이자 소득의 출처는 무엇인가요?"},
        {"question": "소득세법에서 배당소득은 어떻게 정의되나요?"}
    ],
    # 질문에 대한 정답
    outputs=[
        {"answer": "소득세법의 목적은 소득의 성격과 납세자의 부담능력에 따라 적정하게 과세함으로써 조세부담의 형평을 도모하고 재정수입의 원활한 조달에 이바지하는 것입니다."},
        {"answer": "'거주자'는 한국에 주소를 두거나 183일 이상 거소를 둔 개인을 의미합니다."},
        {"answer": "'비거주자'는 거주자가 아닌 개인을 의미합니다."},
        {"answer": "'내국법인'은 법인세법 제2조 제1호에 따른 내국법인을 의미합니다."},
        {"answer": "거주자 및 국내원천소득이 있는 비거주자는 소득세를 납부할 의무가 있습니다."},
        {"answer": "거주자는 법에서 규정한 모든 소득에 대해 과세되며, 비거주자는 국내원천소득에 대해서만 과세됩니다."},
        {"answer": "소득은 종합소득, 퇴직소득, 양도소득으로 분류됩니다."},
        {"answer": "종합소득은 이자소득, 배당소득, 사업소득, 근로소득, 연금소득 및 기타소득을 포함합니다."},
        {"answer": "비과세 소득에는 공익신탁의 이익, 특정 사업소득 및 기타 법에서 정한 특정 소득이 포함됩니다."},
        {"answer": "소득세의 과세기간은 매년 1월 1일부터 12월 31일까지입니다."},
        {"answer": "거주자의 소득세 납세지는 주소지이며, 주소지가 없으면 거소지입니다."},
        {"answer": "비거주자의 소득세 납세지는 국내사업장의 소재지입니다. 국내사업장이 여러 곳인 경우 주된 사업장의 소재지가 납세지가 됩니다."},
        {"answer": "납세지가 불분명한 경우 대통령령으로 정합니다."},
        {"answer": "원천징수세액의 납세지는 원천징수자의 종류와 위치에 따라 결정됩니다."},
        {"answer": "납세자의 사망 시 상속인 또는 납세관리인의 주소지나 거소지가 납세지가 됩니다."},
        {"answer": "신탁 소득에 대한 납세의 범위는 신탁의 수익자가 해당 소득에 대해 납세의무를 집니다."},
        {"answer": "이자소득, 배당소득 및 기타 법에서 정한 소득은 원천징수 대상입니다."},
        {"answer": "공동 소유 자산의 양도소득은 각 거주자 소유 지분에 따라 과세됩니다."},
        {"answer": "이자 소득의 출처는 정부 및 지방자치단체가 발행한 채권, 법인이 발행한 채권, 국내외 은행 예금 등입니다."},
        {"answer": "배당소득은 국내외 법인으로부터 받는 배당금 및 배분금, 기타 법에서 정한 소득을 포함합니다."}
    ],
    # 각 질문이 활용해야 하는 컨텍스트 목록
    metadata= [
        {"context": "제1조(목적) 이 법은 개인의 소득에 대하여 소득의 성격과 납세자의 부담능력 등에 따라 적정하게 과세함으로써 조세부담의 형평을 도모하고 재정수입의 원활한 조달에 이바지함을 목적으로 한다."},
        {"context": "제1조의2(정의) “거주자”란 국내에 주소를 두거나 183일 이상의 거소를 둔 개인을 말한다."},
        {"context": "제1조의2(정의) “비거주자”란 거주자가 아닌 개인을 말한다."},
        {"context": "제1조의2(정의) “내국법인”이란 「법인세법」 제2조제1호에 따른 내국법인을 말한다."},
        {"context": "제2조(납세의무) 거주자 및 국내원천소득이 있는 비거주자는 소득세를 납부할 의무가 있다."},
        {"context": "제3조(과세소득의 범위) 거주자는 법에서 규정한 모든 소득에 대해 과세되며, 비거주자는 국내원천소득에 대해서만 과세된다."},
        {"context": "제4조(소득의 구분) 소득은 종합소득, 퇴직소득, 양도소득으로 분류된다."},
        {"context": "제4조(소득의 구분) 종합소득은 이자소득, 배당소득, 사업소득, 근로소득, 연금소득 및 기타소득을 포함한다."},
        {"context": "제12조(비과세소득) 비과세 소득에는 공익신탁의 이익, 특정 사업소득 및 기타 법에서 정한 특정 소득이 포함된다."},
        {"context": "제5조(과세기간) 소득세의 과세기간은 매년 1월 1일부터 12월 31일까지이다."},
        {"context": "제6조(납세지) 거주자의 소득세 납세지는 주소지이며, 주소지가 없으면 거소지이다."},
        {"context": "제6조(납세지) 비거주자의 소득세 납세지는 국내사업장의 소재지이다. 국내사업장이 여러 곳인 경우 주된 사업장의 소재지이다."},
        {"context": "제6조(납세지) 납세지가 불분명한 경우에는 대통령령으로 정한다."},
        {"context": "제7조(원천징수 등의 경우의 납세지) 원천징수세액의 납세지는 원천징수자의 종류와 위치에 따라 결정된다."},
        {"context": "제8조(상속 등의 경우의 납세지) 납세자의 사망 시 상속인 또는 납세관리인의 주소지나 거소지가 납세지가 된다."},
        {"context": "제2조의3(신탁재산 귀속 소득에 대한 납세의무의 범위) 신탁 소득에 대한 납세의 범위는 신탁의 수익자가 해당 소득에 대해 납세의무를 진다."},
        {"context": "제14조(과세표준의 계산) 이자소득, 배당소득 및 기타 법에서 정한 소득은 원천징수 대상이다."},
        {"context": "제14조(과세표준의 계산) 공동 소유 자산의 양도소득은 각 거주자 소유 지분에 따라 과세된다."},
        {"context": "제16조(이자소득) 이자 소득의 출처는 정부 및 지방자치단체가 발행한 채권, 법인이 발행한 채권, 국내외 은행 예금 등이다."},
        {"context": "제17조(배당소득) 배당소득은 국내외 법인으로부터 받는 배당금 및 배분금, 기타 법에서 정한 소득을 포함한다."}
    ],
    dataset_id=dataset.id,
)
# Out:
# {'example_ids': ['77bd6297-bd9b-4989-adbd-4ecaf2784978',
#   'dda7ff30-2e38-4959-b933-39fa467cb0f7',
#   'cdf79b2c-b8d4-41c7-b1f6-e3cc2e57c02a',
#   '1237652e-a669-453b-8bbb-14249de7cfcb',
#   'a0526549-a62b-4490-b014-b1b8eadd7e07',
#   'a0858413-aee1-4a68-9e04-9a99d91bd5e3',
#   '00d6e7ce-b1f7-4d28-bd8b-268982a7006a',
#   '6bdbeefe-fc1a-4685-8de1-0023585d2be5',
#   'd9f5cba4-6c42-4ace-8220-2c36eed1f18a',
#   '76da1c1c-a63b-4b13-86e5-657b164d1ed9',
#   '7cc3a799-c0b8-49bc-86e9-a37f36ca331e',
#   '2047a21b-7612-478b-b05e-2c4af5d75bc8',
#   '93895908-7c71-4d5a-b1ee-d11a0393719f',
#   '6131e2f1-cf65-4ab7-819d-37252fd1e99a',
#   'adbcc8b9-5e1f-4d2e-875c-4883eeca85da',
#   'aa8bd83f-5f6e-4329-900d-12b00d2f2f79',
#   '2a428525-ec4b-4f58-b261-4b5092cc068a',
#   'ad7f58b7-b04e-4143-844d-40dcd91e32bb',
#   'eba87ded-fa3a-4849-a89d-8bd4a9062249',
#   'f9143b5b-55c8-4af8-8a85-e2006ae59876'],
#  'count': 20}
